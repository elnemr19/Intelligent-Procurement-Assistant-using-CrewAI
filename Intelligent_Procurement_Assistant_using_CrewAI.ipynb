# %% [markdown]
# https://www.youtube.com/watch?v=DDR4A8-MLQs

# %%
# !pip install -qU crewai[tools,agentops]==0.114.0

# %%
# !pip install -qU tavily-python scrapegraph-py

# %%
# !pip install --upgrade litellm

# %%
from crewai import Agent, Task, Crew, Process, LLM
from crewai.tools import tool
from crewai.knowledge.source.string_knowledge_source import StringKnowledgeSource
import agentops
from google.colab import userdata
from pydantic import BaseModel, Field
from typing import List
from tavily import TavilyClient
from scrapegraph_py import Client

import os
import json

# %%
os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')
os.environ["AGENTOPS_API_KEY"] = userdata.get('AgentOps')
os.environ["GEMINI_API_KEY"] = userdata.get('GEMINI_API_KEY')



agentops.init(
    api_key=userdata.get('AgentOps'),
    skip_auto_end_session=True,
    default_tags=['crewai']
)
# Out:
# 🖇 AgentOps: You're on the agentops free plan 🤔

# %%
print(agentops.get_client().config.exporter_endpoint)
# Out:
# https://otlp.agentops.ai/v1/traces

# %%
output_dir = "./ai-agent-output"
os.makedirs(output_dir, exist_ok=True)

basic_llm = LLM(model="groq/llama3-70b-8192", temperature=0)
compound_llm = LLM(model="groq/compound-beta-mini", temperature=0)
#deepseek_llm = LLM(model="groq/deepseek-r1-distill-llama-70b", temperature=0)
gemini_llm = LLM(
    model="gemini/gemini-pro",           # or "gemini-1.5-pro" etc. depending on your quota
    temperature=0
)
search_client = TavilyClient(api_key=userdata.get('tvly-search'))
scrape_client = Client(api_key=userdata.get('scrapegraph'))

# %%
no_keywords = 10

about_company = "Rankyx is a company that provides AI solutions to help websites refine their search and recommendation systems."

company_context = StringKnowledgeSource(
    content=about_company
)

# %% [markdown]
# ## Agent A

# %%
class SuggestedSearchQueries(BaseModel):
    queries: List[str] = Field(..., title="Suggested search queries to be passed to the search engine",
                               min_items=1, max_items=no_keywords)

search_queries_recommendation_agent = Agent(
    role="Search Queries Recommendation Agent",
    goal="\n".join([
                "To provide a list of suggested search queries to be passed to the search engine.",
                "The queries must be varied and looking for specific items."
            ]),
    backstory="The agent is designed to help in looking for products by providing a list of suggested search queries to be passed to the search engine based on the context provided.",
    llm=compound_llm,
    verbose=True,
)

search_queries_recommendation_task = Task(
    description="\n".join([
        "Rankyx is looking to buy {product_name} at the best prices (value for a price strategy)",
        "The campany target any of these websites to buy from: {websites_list}",
        "The company wants to reach all available proucts on the internet to be compared later in another stage.",
        "The stores must sell the product in {country_name}",
        "Generate at maximum {no_keywords} queries.",
        "The search keywords must be in {language} language.",
        "Search keywords must contains specific brands, types or technologies. Avoid general keywords.",
        "The search query must reach an ecommerce webpage for product, and not a blog or listing page."
    ]),
    expected_output="A JSON object containing a list of suggested search queries.",
    output_json=SuggestedSearchQueries,
    output_file=os.path.join(output_dir, "step_1_suggested_search_queries.json"),
    agent=search_queries_recommendation_agent
)

# %% [markdown]
# ## Agent B

# %%
class SignleSearchResult(BaseModel):
    title: str
    url: str = Field(..., title="the page url")
    content: str
    score: float
    search_query: str

class AllSearchResults(BaseModel):
    results: List[SignleSearchResult]

@tool
def search_engine_tool(query: str):
    """Useful for search-based queries. Use this to find current information about any query related pages using a search engine"""
    return search_client.search(query)

search_engine_agent = Agent(
    role="Search Engine Agent",
    goal="To search for products based on the suggested search query",
    backstory="The agent is designed to help in looking for products by searching for products based on the suggested search queries.",
    llm=gemini_llm,
    verbose=True,
    tools=[search_engine_tool]
)

search_engine_task = Task(
    description="\n".join([
        "The task is to search for products based on the suggested search queries.",
        "You have to collect results from multiple search queries.",
        "Ignore any susbicious links or not an ecommerce single product website link.",
        "Ignore any search results with confidence score less than ({score_th}) .",
        "The search results will be used to compare prices of products from different websites.",
    ]),
    expected_output="A JSON object containing the search results.",
    output_json=AllSearchResults,
    output_file=os.path.join(output_dir, "step_2_search_results.json"),
    agent=search_engine_agent
)

# %% [markdown]
# ## Agent C

# %%
class ProductSpec(BaseModel):
    specification_name: str
    specification_value: str

class SingleExtractedProduct(BaseModel):
    page_url: str = Field(..., title="The original url of the product page")
    product_title: str = Field(..., title="The title of the product")
    product_image_url: str = Field(..., title="The url of the product image")
    product_url: str = Field(..., title="The url of the product")
    product_current_price: float = Field(..., title="The current price of the product")
    product_original_price: float = Field(title="The original price of the product before discount. Set to None if no discount", default=None)
    product_discount_percentage: float = Field(title="The discount percentage of the product. Set to None if no discount", default=None)

    product_specs: List[ProductSpec] = Field(..., title="The specifications of the product. Focus on the most important specs to compare.", min_items=1, max_items=5)

    agent_recommendation_rank: int = Field(..., title="The rank of the product to be considered in the final procurement report. (out of 5, Higher is Better) in the recommendation list ordering from the best to the worst")
    agent_recommendation_notes: List[str]  = Field(..., title="A set of notes why would you recommend or not recommend this product to the company, compared to other products.")


class AllExtractedProducts(BaseModel):
    products: List[SingleExtractedProduct]


@tool
def web_scraping_tool(page_url: str):
    """
    An AI Tool to help an agent to scrape a web page

    Example:
    web_scraping_tool(
        page_url="https://www.noon.com/egypt-en/15-bar-fully-automatic-espresso-machine-1-8-l-1500"
    )
    """
    details = scrape_client.smartscraper(
        website_url=page_url,
        user_prompt="Extract ```json\n" + SingleExtractedProduct.schema_json() + "```\n From the web page"
    )

    return {
        "page_url": page_url,
        "details": details
    }

scraping_agent = Agent(
    role="Web scraping agent",
    goal="To extract details from any website",
    backstory="The agent is designed to help in looking for required values from any website url. These details will be used to decide which best product to buy.",
    llm=gemini_llm,
    tools=[web_scraping_tool],
    verbose=True,
)

scraping_task = Task(
    description="\n".join([
        "The task is to extract product details from any ecommerce store page url.",
        "The task has to collect results from multiple pages urls.",
        "Collect the best {top_recommendations_no} products from the search results.",
    ]),
    expected_output="A JSON object containing products details",
    output_json=AllExtractedProducts,
    output_file=os.path.join(output_dir, "step_3_search_results.json"),
    agent=scraping_agent
)

# %% [markdown]
# ## Agent D

# %%
procurement_report_author_agent = Agent(
    role="Procurement Report Author Agent",
    goal="To generate a professional HTML page for the procurement report",
    backstory="The agent is designed to assist in generating a professional HTML page for the procurement report after looking into a list of products.",
    llm=gemini_llm,
    verbose=True,
)

procurement_report_author_task = Task(
    description="\n".join([
        "The task is to generate a professional HTML page for the procurement report.",
        "You have to use Bootstrap CSS framework for a better UI.",
        "Use the provided context about the company to make a specialized report.",
        "The report will include the search results and prices of products from different websites.",
        "The report should be structured with the following sections:",
        "1. Executive Summary: A brief overview of the procurement process and key findings.",
        "2. Introduction: An introduction to the purpose and scope of the report.",
        "3. Methodology: A description of the methods used to gather and compare prices.",
        "4. Findings: Detailed comparison of prices from different websites, including tables and charts.",
        "5. Analysis: An analysis of the findings, highlighting any significant trends or observations.",
        "6. Recommendations: Suggestions for procurement based on the analysis.",
        "7. Conclusion: A summary of the report and final thoughts.",
        "8. Appendices: Any additional information, such as raw data or supplementary materials.",
    ]),

    expected_output="A professional HTML page for the procurement report.",
    output_file=os.path.join(output_dir, "step_4_procurement_report.html"),
    agent=procurement_report_author_agent,
)

# %% [markdown]
# ## Run AI Crew

# %%
rankyx_crew = Crew(
    agents=[
        search_queries_recommendation_agent,
        search_engine_agent,
        scraping_agent,
        procurement_report_author_agent,
    ],
    tasks=[
        search_queries_recommendation_task,
        search_engine_task,
        scraping_task,
        procurement_report_author_task,
    ],
    process=Process.sequential,
    knowledge_sources=[company_context]
)

# %%
crew_results = rankyx_crew.kickoff(
    inputs={
        "product_name": "coffee machine for the office",
        "websites_list": ["www.amazon.eg", "www.jumia.com.eg", "www.noon.com/egypt-en"],
        "country_name": "Egypt",
        "no_keywords": 10,
        "language": "English",
        "score_th": 0.10,
        "top_recommendations_no": 10
    }
)
# Out:
# # Agent: Search Queries Recommendation Agent
# ## Task: Rankyx is looking to buy coffee machine for the office at the best prices (value for a price strategy)
# The campany target any of these websites to buy from: ['www.amazon.eg', 'www.jumia.com.eg', 'www.noon.com/egypt-en']
# The company wants to reach all available proucts on the internet to be compared later in another stage.
# The stores must sell the product in Egypt
# Generate at maximum 10 queries.
# The search keywords must be in English language.
# Search keywords must contains specific brands, types or technologies. Avoid general keywords.
# The search query must reach an ecommerce webpage for product, and not a blog or listing page.
#
#
# # Agent: Search Queries Recommendation Agent
# ## Final Answer:
# {
#   "queries": [
#     "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt",
#     "site:www.jumia.com.eg 'Nespresso coffee machine' Egypt",
#     "site:www.noon.com/egypt-en 'Siemens coffee machine' office use",
#     "site:www.amazon.eg 'Bosch coffee machine' with grinder Egypt",
#     "site:www.jumia.com.eg 'Philips coffee machine' with milk frother Egypt",
#     "site:www.noon.com/egypt-en 'Krups coffee machine' espresso maker Egypt",
#     "site:www.amazon.eg 'Melitta coffee machine' with thermal carafe Egypt",
#     "site:www.jumia.com.eg 'Russell Hobbs coffee machine' with timer Egypt",
#     "site:www.noon.com/egypt-en 'Breville coffee machine' with built-in grinder Egypt",
#     "site:www.amazon.eg 'Keurig coffee machine' single serve Egypt"
#   ]
# }
#
#
# # Agent: Search Engine Agent
# ## Task: The task is to search for products based on the suggested search queries.
# You have to collect results from multiple search queries.
# Ignore any susbicious links or not an ecommerce single product website link.
# Ignore any search results with confidence score less than (0.1) .
# The search results will be used to compare prices of products from different websites.
#
#
# # Agent: Search Engine Agent
# ## Thought: I need to perform a series of searches using the search_engine_tool to gather product information from different websites in Egypt. The search queries are focused on specific coffee machine brands and features. I will then compile the results into a JSON object as requested.
# json
# {
#   "results": []
# }
# I will now proceed with the first search query.
# Thought: I will start with the first search query and then proceed with the rest, compiling the results into the JSON object.
# ## Using tool: search_engine_tool
# ## Tool Input:
# "{\"query\": \"site:www.amazon.eg 'De'Longhi coffee machine' in Egypt\"}"
# ## Tool Output:
# {'query': "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt", 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s?rh=n%3A21863852031%2Cp_89%3ADe%2527Longhi', 'title': "De'Longhi - Coffee, Tea & Espresso / Kitchen & Dining", 'content': "Price, product pageEGP 890.00 EGP 890.00 List: EGP 1,299.00 List: EGP 1,299.00 EGP1,299.00 *   [- [x] Fulfilled by Amazon](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Free Shipping All customers get FREE Shipping on orders shipped by Amazon](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? i=home&rh=n%3A21863852031%2Cp_89%3ADe%2527Longhi%2Cp_n_free_shipping_eligible%3A21909080031&dc&language=en&qid=1752169469&rnid=21909079031&ref=sr_nr_p_n_free_shipping_eligible_1&ds=v1%3Af7IWxIXQKfkZlZbd5Gvv%2BSkDz83Yatenbw3fOaWQrpY) *   [- [x] Get It by Tomorrow](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] De'Longhi](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Black & Decker](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Arzum Okka](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Nespresso](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Mienta](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Tornado](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] PHILIPS](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] NESCAFÉ DOLCE GUSTO](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Arzum](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Amazon.eg](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Rose Smile Store](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] NM-Espresso](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] QTECH.STORE](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Oxeev](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Ocean Electronics](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] LaialStore](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Include Out of Stock](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s?", 'score': 0.8747745, 'raw_content': None}, {'url': 'https://www.amazon.eg/-/en/DeLonghi-31-21-coffee-machine-black/dp/B013GDEAI0', 'title': "De'Longhi ecp 31.21 coffee machine (black, 1100w)", 'content': "Buy De'Longhi ecp 31.21 coffee machine (black, 1100w) online on Amazon.eg at best prices. ✓ Fast and Free Shipping ✓ Free Returns ✓Cash on Delivery", 'score': 0.80771893, 'raw_content': None}, {'url': 'https://www.amazon.eg/-/en/Espresso-Machines-DeLonghi-Coffee/s?rh=n%3A21864618031%2Cp_89%3ADe%2527Longhi', 'title': "De'Longhi - Coffee Machines", 'content': "De'Longhi - Espresso Machines / Coffee Machines : Shop online for a large selection of top brands in Egypt ... De'Longhi ecp 31.21 coffee machine (black, 1100w).", 'score': 0.6504012, 'raw_content': None}, {'url': 'https://www.amazon.eg/-/en/delonghi/s?k=delonghi', 'title': 'Delonghi: Shop Online At Best Prices In Egypt', 'content': 'Delonghi Ec221 Pump Espresso & Coffee Machine, 1.4L, Black ... Only 2 left in stock - order soon.', 'score': 0.54492307, 'raw_content': None}, {'url': 'https://www.amazon.eg/-/en/DeLonghi-Rivelia-EXAM440-55-W-Automatic-LatteCrema/dp/B0CDCM3J5G', 'title': "De'Longhi Rivelia EXAM440.55.W, Fully Automatic Coffee ...", 'content': 'Fully Automatic Coffee Maker with LatteCrema, Automatic Milk Frot ...
#
#
# You ONLY have access to the following tools, and should NEVER make up tools that are not listed here:
#
# Tool Name: search_engine_tool
# Tool Arguments: {'query': {'description': None, 'type': 'str'}}
# Tool Description: Useful for search-based queries. Use this to find current information about any query related pages using a search engine
#
# IMPORTANT: Use the following format in your response:
#
# ```
# Thought: you should always think about what to do
# Action: the action to take, only one name of [search_engine_tool], just the name, exactly as it's written.
# Action Input: the input to the action, just a simple JSON object, enclosed in curly braces, using " to wrap keys and values.
# Observation: the result of the action
# ```
#
# Once all necessary information is gathered, return the following format:
#
# ```
# Thought: I now know the final answer
# Final Answer: the final answer to the original input question
# ```
#
#
# # Agent: Search Engine Agent
# ## Thought: json
# {
#   "results": [
#     {
#       "title": "De'Longhi - Coffee, Tea & Espresso / Kitchen & Dining",
#       "url": "https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s?rh=n%3A21863852031%2Cp_89%3ADe%2527Longhi",
#       "content": "Price, product pageEGP 890.00 EGP 890.00 List: EGP 1,299.00 List: EGP 1,299.00 EGP1,299.00 *   [- [x] Fulfilled by Amazon](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Free Shipping All customers get FREE Shipping on orders shipped by Amazon](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? i=home&rh=n%3A21863852031%2Cp_89%3ADe%2527Longhi%2Cp_n_free_shipping_eligible%3A21909080031&dc&language=en&qid=1752169469&rnid=21909079031&ref=sr_nr_p_n_free_shipping_eligible_1&ds=v1%3Af7IWxIXQKfkZlZbd5Gvv%2BSkDz83Yatenbw3fOaWQrpY) *   [- [x] Get It by Tomorrow](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] De'Longhi](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Black & Decker](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Arzum Okka](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Nespresso](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Mienta](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Tornado](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] PHILIPS](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] NESCAFÉ DOLCE GUSTO](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Arzum](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Amazon.eg](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Rose Smile Store](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] NM-Espresso](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] QTECH.STORE](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Oxeev](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Ocean Electronics](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] LaialStore](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Include Out of Stock](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s?",
#       "score": 0.8747745,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "De'Longhi ecp 31.21 coffee machine (black, 1100w)",
#       "url": "https://www.amazon.eg/-/en/DeLonghi-31-21-coffee-machine-black/dp/B013GDEAI0",
#       "content": "Buy De'Longhi ecp 31.21 coffee machine (black, 1100w) online on Amazon.eg at best prices. ✓ Fast and Free Shipping ✓ Free Returns ✓Cash on Delivery",
#       "score": 0.80771893,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "De'Longhi - Coffee Machines",
#       "url": "https://www.amazon.eg/-/en/Espresso-Machines-DeLonghi-Coffee/s?rh=n%3A21864618031%2Cp_89%3ADe%2527Longhi",
#       "content": "De'Longhi - Espresso Machines / Coffee Machines : Shop online for a large selection of top brands in Egypt ... De'Longhi ecp 31.21 coffee machine (black, 1100w).",
#       "score": 0.6504012,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "Delonghi: Shop Online At Best Prices In Egypt",
#       "url": "https://www.amazon.eg/-/en/delonghi/s?k=delonghi",
#       "content": "Delonghi Ec221 Pump Espresso & Coffee Machine, 1.4L, Black ... Only 2 left in stock - order soon.",
#       "score": 0.54492307,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "De'Longhi Rivelia EXAM440.55.W, Fully Automatic Coffee ...",
#       "url": "https://www.amazon.eg/-/en/DeLonghi-Rivelia-EXAM440-55-W-Automatic-LatteCrema/dp/B0CDCM3J5G",
#       "content": "Fully Automatic Coffee Maker with LatteCrema, Automatic Milk Frother, Compact Size, Bean-to-Cup Coffee Maker, 16 Recipes, Colored Touch Display, Arctic White",
#       "score": 0.32088566,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     }
#   ]
# }
# Now I will proceed with the second search query.
# Thought: Now I will search for the second query and add the results to the JSON object.
# ## Using tool: search_engine_tool
# ## Tool Input:
# "{\"query\": \"site:www.jumia.com.eg 'Nespresso coffee machine' Egypt\"}"
# ## Tool Output:
# {'query': "site:www.jumia.com.eg 'Nespresso coffee machine' Egypt", 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.jumia.com.eg/nespresso-inissia-coffee-machine-black-133536518.html?srsltid=AfmBOoq3MML5Yk3jZ5qXcQulpC-r38aFThKjqz-bo5pZ1CMCRnsuvtda', 'title': 'Nespresso Inissia Coffee Machine Black', 'content': 'Nespresso Inissia Coffee Machine Black. Brand:Nespresso|Similar products from Nespresso. EGP 8,569.00. Few units left. Free delivery to 6th of', 'score': 0.69399214, 'raw_content': None}, {'url': 'https://www.jumia.com.eg/coffee-machines/nespresso/?srsltid=AfmBOop0Tr93xKdpASBt9R9LkErAVxzDStcTUWzcpsBz5Bv7-J2MHoxh', 'title': 'Nespresso Coffee Machines - Best Prices in Egypt', 'content': 'Nespresso Coffee Machine, 6 Cups, 19 Bars, 1260W, with Aeroccino 3 Milk Frother, Black - D40-BK. EGP 10,999.00EGP 13,500.00. Add to cart.', 'score': 0.66621506, 'raw_content': None}, {'url': 'https://www.jumia.com.eg/mlp-nespresso-machines/?srsltid=AfmBOorRhywqweFQ83vKw1p92u9yVUOWpi-hBJUo42xjYzCH7Io0nVyW', 'title': 'Buy Nespresso Machines at Best Prices', 'content': 'Nespresso Coffee Machine, 6 Cups, 19 Bars, 1260W, with Aeroccino 3 Milk Frother, Black - D40-BK. EGP 10,999.00EGP 13,500.00. Add to cart.', 'score': 0.6580885, 'raw_content': None}, {'url': 'https://www.jumia.com.eg/super-automatic-espresso-machines/nespresso/?srsltid=AfmBOopDWq8iU2_s4p_HSvNg72BCjgsWxX27Kz8Zs6lzsW9ivQRhic6f', 'title': 'Nespresso Super-Automatic Espresso Machines', 'content': 'Wide Selection of Nespresso Super-Automatic Espresso Machines in Egypt ... Nespresso Inissia Coffee Machine Black. EGP 8,569.00. Add to cart. Sort by', 'score': 0.61668247, 'raw_content': None}, {'url': 'https://www.jumia.com.eg/nespresso-coffee-machine-6-cups-19-bars-1260w-with-aeroccino-3-milk-frother-black-d40-bk-133386173.html?srsltid=AfmBOopnrIHA0M8UVycrzs7dMfwMqQKqelhCnyrwSnaMb4zX39c0QOfQ', 'title': 'Coffee Machine, 6 Cups, 19 Bars, 1260W, with Aeroccino ...', 'content': 'Get Nespresso Coffee Machine, 6 Cups, 19 Bars, 1260W, with Aeroccino 3 Milk Frother, Black - D40-BK online at Jumia and other Nespresso Coffee Machines at', 'score': 0.5843666, 'raw_content': None}], 'response_time': 1.25}
#
#
# # Agent: Search Engine Agent
# ## Thought: json
# {
#   "results": [
#     {
#       "title": "De'Longhi - Coffee, Tea & Espresso / Kitchen & Dining",
#       "url": "https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s?rh=n%3A21863852031%2Cp_89%3ADe%2527Longhi",
#       "content": "Price, product pageEGP 890.00 EGP 890.00 List: EGP 1,299.00 List: EGP 1,299.00 EGP1,299.00 *   [- [x] Fulfilled by Amazon](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Free Shipping All customers get FREE Shipping on orders shipped by Amazon](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? i=home&rh=n%3A21863852031%2Cp_89%3ADe%2527Longhi%2Cp_n_free_shipping_eligible%3A21909080031&dc&language=en&qid=1752169469&rnid=21909079031&ref=sr_nr_p_n_free_shipping_eligible_1&ds=v1%3Af7IWxIXQKfkZlZbd5Gvv%2BSkDz83Yatenbw3fOaWQrpY) *   [- [x] Get It by Tomorrow](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] De'Longhi](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Black & Decker](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Arzum Okka](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Nespresso](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Mienta](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Tornado](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] PHILIPS](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] NESCAFÉ DOLCE GUSTO](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Arzum](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Amazon.eg](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Rose Smile Store](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] NM-Espresso](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] QTECH.STORE](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Oxeev](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Ocean Electronics](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] LaialStore](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s?",
#       "score": 0.8747745,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "De'Longhi ecp 31.21 coffee machine (black, 1100w)",
#       "url": "https://www.amazon.eg/-/en/DeLonghi-31-21-coffee-machine-black/dp/B013GDEAI0",
#       "content": "Buy De'Longhi ecp 31.21 coffee machine (black, 1100w) online on Amazon.eg at best prices. ✓ Fast and Free Shipping ✓ Free Returns ✓Cash on Delivery",
#       "score": 0.80771893,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "De'Longhi - Coffee Machines",
#       "url": "https://www.amazon.eg/-/en/Espresso-Machines-DeLonghi-Coffee/s?rh=n%3A21864618031%2Cp_89%3ADe%2527Longhi",
#       "content": "De'Longhi - Espresso Machines / Coffee Machines : Shop online for a large selection of top brands in Egypt ... De'Longhi ecp 31.21 coffee machine (black, 1100w).",
#       "score": 0.6504012,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "Delonghi: Shop Online At Best Prices In Egypt",
#       "url": "https://www.amazon.eg/-/en/delonghi/s?k=delonghi",
#       "content": "Delonghi Ec221 Pump Espresso & Coffee Machine, 1.4L, Black ... Only 2 left in stock - order soon.",
#       "score": 0.54492307,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "De'Longhi Rivelia EXAM440.55.W, Fully Automatic Coffee ...",
#       "url": "https://www.amazon.eg/-/en/DeLonghi-Rivelia-EXAM440-55-W-Automatic-LatteCrema/dp/B0CDCM3J5G",
#       "content": "Fully Automatic Coffee Maker with LatteCrema, Automatic Milk Frother, Compact Size, Bean-to-Cup Coffee Maker, 16 Recipes, Colored Touch Display, Arctic White",
#       "score": 0.32088566,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "Nespresso Inissia Coffee Machine Black",
#       "url": "https://www.jumia.com.eg/nespresso-inissia-coffee-machine-black-133536518.html?srsltid=AfmBOoq3MML5Yk3jZ5qXcQulpC-r38aFThKjqz-bo5pZ1CMCRnsuvtda",
#       "content": "Nespresso Inissia Coffee Machine Black. Brand:Nespresso|Similar products from Nespresso. EGP 8,569.00. Few units left. Free delivery to 6th of",
#       "score": 0.69399214,
#       "search_query": "site:www.jumia.com.eg 'Nespresso coffee machine' Egypt"
#     },
#     {
#       "title": "Nespresso Coffee Machines - Best Prices in Egypt",
#       "url": "https://www.jumia.com.eg/coffee-machines/nespresso/?srsltid=AfmBOop0Tr93xKdpASBt9R9LkErAVxzDStcTUWzcpsBz5Bv7-J2MHoxh",
#       "content": "Nespresso Coffee Machine, 6 Cups, 19 Bars, 1260W, with Aeroccino 3 Milk Frother, Black - D40-BK. EGP 10,999.00EGP 13,500.00. Add to cart.",
#       "score": 0.66621506,
#       "search_query": "site:www.jumia.com.eg 'Nespresso coffee machine' Egypt"
#     },
#     {
#       "title": "Buy Nespresso Machines at Best Prices",
#       "url": "https://www.jumia.com.eg/mlp-nespresso-machines/?srsltid=AfmBOorRhywqweFQ83vKw1p92u9yVUOWpi-hBJUo42xjYzCH7Io0nVyW",
#       "content": "Nespresso Coffee Machine, 6 Cups, 19 Bars, 1260W, with Aeroccino 3 Milk Frother, Black - D40-BK. EGP 10,999.00EGP 13,500.00. Add to cart.",
#       "score": 0.6580885,
#       "search_query": "site:www.jumia.com.eg 'Nespresso coffee machine' Egypt"
#     },
#     {
#       "title": "Nespresso Super-Automatic Espresso Machines",
#       "url": "https://www.jumia.com.eg/super-automatic-espresso-machines/nespresso/?srsltid=AfmBOopDWq8iU2_s4p_HSvNg72BCjgsWxX27Kz8Zs6lzsW9ivQRhic6f",
#       "content": "Wide Selection of Nespresso Super-Automatic Espresso Machines in Egypt ... Nespresso Inissia Coffee Machine Black. EGP 8,569.00. Add to cart. Sort by",
#       "score": 0.61668247,
#       "search_query": "site:www.jumia.com.eg 'Nespresso coffee machine' Egypt"
#     },
#     {
#       "title": "Coffee Machine, 6 Cups, 19 Bars, 1260W, with Aeroccino ...",
#       "url": "https://www.jumia.com.eg/nespresso-coffee-machine-6-cups-19-bars-1260w-with-aeroccino-3-milk-frother-black-d40-bk-133386173.html?srsltid=AfmBOopnrIHA0M8UVycrzs7dMfwMqQKqelhCnyrwSnaMb4zX39c0QOfQ",
#       "content": "Get Nespresso Coffee Machine, 6 Cups, 19 Bars, 1260W, with Aeroccino 3 Milk Frother, Black - D40-BK online at Jumia and other Nespresso Coffee Machines at",
#       "score": 0.5843666,
#       "search_query": "site:www.jumia.com.eg 'Nespresso coffee machine' Egypt"
#     }
#   ]
# }
# Now I will proceed with the third search query.
# Thought: Now I will search for the third query and add the results to the JSON object.
# ## Using tool: search_engine_tool
# ## Tool Input:
# "{\"query\": \"site:www.noon.com/egypt-en 'Siemens coffee machine' office use\"}"
# ## Tool Output:
# {'query': "site:www.noon.com/egypt-en 'Siemens coffee machine' office use", 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.noon.com/egypt-en/home-and-kitchen/?f[new_arrivals][]=30_days&sort[by]=popularity&sort[dir]=desc&limit=50&page=1&isCarouselView=false', 'title': 'Home & Kitchen Egypt | Best Price Offers | Cairo, Giza', 'content': 'Nespresso Essenza Mini Coffee Machine - 0.6 L 1 W C30-EU2-SI-NE Silver ... Leakproof Design and Great Gift for Outdoor, Office, Home, Sports - Coffee ... Siemens', 'score': 0.4654124, 'raw_content': None}, {'url': 'https://www.noon.com/egypt-en/home-and-kitchen/home-appliances-31235/eg-kitchen-appliances/?f[is_fbn][]=1&sort[by]=new_arrivals&sort[dir]=desc&limit=50&page=1&isCarouselView=false', 'title': 'Kitchen & Home Appliances Egypt | Best Price Offers | Cairo, Giza', 'content': 'Electric Coffee Pot 800W – Compact & Easy Use – 0.5L Capacity ... Nespresso Essenza Mini Coffee Machine - 0.6 L 1 W C30-EU2-SI-NE Silver ... Siemens Air', 'score': 0.28188768, 'raw_content': None}, {'url': 'https://www.noon.com/egypt-en/home-and-kitchen/home-appliances-31235/black_and_white/', 'title': 'Black & White Kitchen & Home Appliances Egypt', 'content': 'Shop for Black & White Kitchen & Home Appliances on noon. ✓ Secure Shopping ✓ 100% Contactless ✓ Fast Shipping ✓ Cash on Delivery ✓ Easy Free Returns.', 'score': 0.23393422, 'raw_content': None}, {'url': 'https://www.noon.com/egypt-en/home-and-kitchen/home-appliances-31235/arzum/', 'title': 'Arzum Kitchen & Home Appliances Egypt | 30-75% OFF', 'content': 'Arzum Okka Espresso Pro fully Automatic Espresso Machine,1.8L Water Capacity, Double Espresso, Americano, Cold Americano, Powdered Coffee, Milk Foam,', 'score': 0.10296147, 'raw_content': None}, {'url': 'https://www.noon.com/egypt-en/home-and-kitchen/home-appliances-31235/jamaky_italy/', 'title': 'JAMAKY Italy Kitchen & Home Appliances Egypt', 'content': 'JAMAKY Italy JMK9012 Multi Capsule Coffee Maker with Italian technology , Household 1450W Automatic Drip Coffee Machine 0.6L Water Capacity. EGP5,999. 8,50029', 'score': 0.085778356, 'raw_content': None}], 'response_time': 1.07}
#
#
# # Agent: Search Engine Agent
# ## Thought: json
# {
#   "results": [
#     {
#       "title": "De'Longhi - Coffee, Tea & Espresso / Kitchen & Dining",
#       "url": "https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s?rh=n%3A21863852031%2Cp_89%3ADe%2527Longhi",
#       "content": "Price, product pageEGP 890.00 EGP 890.00 List: EGP 1,299.00 List: EGP 1,299.00 EGP1,299.00 *   [- [x] Fulfilled by Amazon](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Free Shipping All customers get FREE Shipping on orders shipped by Amazon](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? i=home&rh=n%3A21863852031%2Cp_89%3ADe%2527Longhi%2Cp_n_free_shipping_eligible%3A21909080031&dc&language=en&qid=1752169469&rnid=21909079031&ref=sr_nr_p_n_free_shipping_eligible_1&ds=v1%3Af7IWxIXQKfkZlZbd5Gvv%2BSkDz83Yatenbw3fOaWQrpY) *   [- [x] Get It by Tomorrow](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] De'Longhi](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Black & Decker](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Arzum Okka](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Nespresso](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Mienta](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Tornado](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] PHILIPS](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] NESCAFÉ DOLCE GUSTO](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Arzum](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Amazon.eg](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Rose Smile Store](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] NM-Espresso](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] QTECH.STORE](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Oxeev](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Ocean Electronics](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] LaialStore](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s?",
#       "score": 0.8747745,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "De'Longhi ecp 31.21 coffee machine (black, 1100w)",
#       "url": "https://www.amazon.eg/-/en/DeLonghi-31-21-coffee-machine-black/dp/B013GDEAI0",
#       "content": "Buy De'Longhi ecp 31.21 coffee machine (black, 1100w) online on Amazon.eg at best prices. ✓ Fast and Free Shipping ✓ Free Returns ✓Cash on Delivery",
#       "score": 0.80771893,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "De'Longhi - Coffee Machines",
#       "url": "https://www.amazon.eg/-/en/Espresso-Machines-DeLonghi-Coffee/s?rh=n%3A21864618031%2Cp_89%3ADe%2527Longhi",
#       "content": "De'Longhi - Espresso Machines / Coffee Machines : Shop online for a large selection of top brands in Egypt ... De'Longhi ecp 31.21 coffee machine (black, 1100w).",
#       "score": 0.6504012,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "Delonghi: Shop Online At Best Prices In Egypt",
#       "url": "https://www.amazon.eg/-/en/delonghi/s?k=delonghi",
#       "content": "Delonghi Ec221 Pump Espresso & Coffee Machine, 1.4L, Black ... Only 2 left in stock - order soon.",
#       "score": 0.54492307,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "De'Longhi Rivelia EXAM440.55.W, Fully Automatic Coffee ...",
#       "url": "https://www.amazon.eg/-/en/DeLonghi-Rivelia-EXAM440-55-W-Automatic-LatteCrema/dp/B0CDCM3J5G",
#       "content": "Fully Automatic Coffee Maker with LatteCrema, Automatic Milk Frother, Compact Size, Bean-to-Cup Coffee Maker, 16 Recipes, Colored Touch Display, Arctic White",
#       "score": 0.32088566,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "Nespresso Inissia Coffee Machine Black",
#       "url": "https://www.jumia.com.eg/nespresso-inissia-coffee-machine-black-133536518.html?srsltid=AfmBOoq3MML5Yk3jZ5qXcQulpC-r38aFThKjqz-bo5pZ1CMCRnsuvtda",
#       "content": "Nespresso Inissia Coffee Machine Black. Brand:Nespresso|Similar products from Nespresso. EGP 8,569.00. Few units left. Free delivery to 6th of",
#       "score": 0.69399214,
#       "search_query": "site:www.jumia.com.eg 'Nespresso coffee machine' Egypt"
#     },
#     {
#       "title": "Nespresso Coffee Machines - Best Prices in Egypt",
#       "url": "https://www.jumia.com.eg/coffee-machines/nespresso/?srsltid=AfmBOop0Tr93xKdpASBt9R9LkErAVxzDStcTUWzcpsBz5Bv7-J2MHoxh",
#       "content": "Nespresso Coffee Machine, 6 Cups, 19 Bars, 1260W, with Aeroccino 3 Milk Frother, Black - D40-BK. EGP 10,999.00EGP 13,500.00. Add to cart.",
#       "score": 0.66621506,
#       "search_query": "site:www.jumia.com.eg 'Nespresso coffee machine' Egypt"
#     },
#     {
#       "title": "Buy Nespresso Machines at Best Prices",
#       "url": "https://www.jumia.com.eg/mlp-nespresso-machines/?srsltid=AfmBOorRhywqweFQ83vKw1p92u9yVUOWpi-hBJUo42xjYzCH7Io0nVyW",
#       "content": "Nespresso Coffee Machine, 6 Cups, 19 Bars, 1260W, with Aeroccino 3 Milk Frother, Black - D40-BK. EGP 10,999.00EGP 13,500.00. Add to cart.",
#       "score": 0.6580885,
#       "search_query": "site:www.jumia.com.eg 'Nespresso coffee machine' Egypt"
#     },
#     {
#       "title": "Nespresso Super-Automatic Espresso Machines",
#       "url": "https://www.jumia.com.eg/super-automatic-espresso-machines/nespresso/?srsltid=AfmBOopDWq8iU2_s4p_HSvNg72BCjgsWxX27Kz8Zs6lzsW9ivQRhic6f",
#       "content": "Wide Selection of Nespresso Super-Automatic Espresso Machines in Egypt ... Nespresso Inissia Coffee Machine Black. EGP 8,569.00. Add to cart. Sort by",
#       "score": 0.61668247,
#       "search_query": "site:www.jumia.com.eg 'Nespresso coffee machine' Egypt"
#     },
#     {
#       "title": "Coffee Machine, 6 Cups, 19 Bars, 1260W, with Aeroccino ...",
#       "url": "https://www.jumia.com.eg/nespresso-coffee-machine-6-cups-19-bars-1260w-with-aeroccino-3-milk-frother-black-d40-bk-133386173.html?srsltid=AfmBOopnrIHA0M8UVycrzs7dMfwMqQKqelhCnyrwSnaMb4zX39c0QOfQ",
#       "content": "Get Nespresso Coffee Machine, 6 Cups, 19 Bars, 1260W, with Aeroccino 3 Milk Frother, Black - D40-BK online at Jumia and other Nespresso Coffee Machines at",
#       "score": 0.5843666,
#       "search_query": "site:www.jumia.com.eg 'Nespresso coffee machine' Egypt"
#     },
#     {
#       "title": "Home & Kitchen Egypt | Best Price Offers | Cairo, Giza",
#       "url": "https://www.noon.com/egypt-en/home-and-kitchen/?f[new_arrivals][]=30_days&sort[by]=popularity&sort[dir]=desc&limit=50&page=1&isCarouselView=false",
#       "content": "Nespresso Essenza Mini Coffee Machine - 0.6 L 1 W C30-EU2-SI-NE Silver ... Leakproof Design and Great Gift for Outdoor, Office, Home, Sports - Coffee ... Siemens",
#       "score": 0.4654124,
#       "search_query": "site:www.noon.com/egypt-en 'Siemens coffee machine' office use"
#     },
#     {
#       "title": "Kitchen & Home Appliances Egypt | Best Price Offers | Cairo, Giza",
#       "url": "https://www.noon.com/egypt-en/home-and-kitchen/home-appliances-31235/eg-kitchen-appliances/?f[is_fbn][]=1&sort[by]=new_arrivals&sort[dir]=desc&limit=50&page=1&isCarouselView=false",
#       "content": "Electric Coffee Pot 800W – Compact & Easy Use – 0.5L Capacity ... Nespresso Essenza Mini Coffee Machine - 0.6 L 1 W C30-EU2-SI-NE Silver ... Siemens Air",
#       "score": 0.28188768,
#       "search_query": "site:www.noon.com/egypt-en 'Siemens coffee machine' office use"
#     },
#     {
#       "title": "Black & White Kitchen & Home Appliances Egypt",
#       "url": "https://www.noon.com/egypt-en/home-and-kitchen/home-appliances-31235/black_and_white/",
#       "content": "Shop for Black & White Kitchen & Home Appliances on noon. ✓ Secure Shopping ✓ 100% Contactless ✓ Fast Shipping ✓ Cash on Delivery ✓ Easy Free Returns.",
#       "score": 0.23393422,
#       "search_query": "site:www.noon.com/egypt-en 'Siemens coffee machine' office use"
#     },
#     {
#       "title": "Arzum Kitchen & Home Appliances Egypt | 30-75% OFF",
#       "url": "https://www.noon.com/egypt-en/home-and-kitchen/home-appliances-31235/arzum/",
#       "content": "Arzum Okka Espresso Pro fully Automatic Espresso Machine,1.8L Water Capacity, Double Espresso, Americano, Cold Americano, Powdered Coffee, Milk Foam,",
#       "score": 0.10296147,
#       "search_query": "site:www.noon.com/egypt-en 'Siemens coffee machine' office use"
#     }
#   ]
# }
# Now I will proceed with the fourth search query.
# Thought: Now I will search for the fourth query and add the results to the JSON object.
# ## Using tool: search_engine_tool
# ## Tool Input:
# "{\"query\": \"site:www.amazon.eg 'Bosch coffee machine' with grinder Egypt\"}"
# ## Tool Output:
# {'query': "site:www.amazon.eg 'Bosch coffee machine' with grinder Egypt", 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.amazon.eg/-/en/Bosch-Automatic-container-Capacity-TIE20119/dp/B0CP4JY87P', 'title': 'Bosch Fully Automatic Coffee machine Series 2 bean ...', 'content': 'EGP35,999.00 ; FREE delivery Wednesday, 30 July ; Fulfilled by. Amazon ; Sold by. المفيد-للتجاره ; Brand · bosch', 'score': 0.6391287, 'raw_content': None}, {'url': 'https://www.amazon.eg/-/en/Bosch-TIS30129RW-automatic-machine-VeroCup/dp/B07HLD1THX', 'title': 'TIS30129RW - Fully automatic coffee machine VeroCup 100', 'content': 'Bosch Fully automatic coffee machine VeroCup 100; Color : Black; Package ... Ceramic grinder: Lasting enjoyment thanks to a high-quality grinder made of', 'score': 0.3599269, 'raw_content': None}, {'url': 'https://www.amazon.eg/-/en/Coffee-Tea-Espresso-Bosch-Kitchen-Dining/s?rh=n%3A21863852031%2Cp_89%3ABosch', 'title': 'Bosch - Coffee, Tea & Espresso / Kitchen & Dining', 'content': 'Bosch Coffee Electric Grinder 150G/Min, 180 W, Black – TSM6A013B · Plastic ... Bosch Coffee Machine Digital With Milk container Vero Barista 600 - TIS65621RW.', 'score': 0.3369858, 'raw_content': None}, {'url': 'https://www.amazon.eg/-/en/Bosch-coffee-machine-automatic-Barista/dp/B09P3WWFLS', 'title': 'Bosch coffee machine Full automatic, Vero Barista, 1500 W', 'content': 'Special Features: Timer, Water Filter, Milk Frother, Permanent Filter, Thermal. Coffee Maker Type: Espresso Machine. Material: Ceramic.', 'score': 0.26213333, 'raw_content': None}, {'url': 'https://www.amazon.eg/-/en/Coffee-Tea-Espresso-Bosch-Kitchen-Dining/s?rh=n%3A21863852031%2Cp_89%3ABosch&page=2&ref=is_ps_1', 'title': 'Bosch - Coffee, Tea & Espresso / Kitchen & Dining', 'content': 'Bosch Fully automatic coffee machine Series 2 - Pump pressure 15.0 bar - Volume water tank 1.4 l - Capacity bean container 250 g - Silver - TIE20301.', 'score': 0.2456686, 'raw_content': None}], 'response_time': 1.12}
#
#
# You ONLY have access to the following tools, and should NEVER make up tools that are not listed here:
#
# Tool Name: search_engine_tool
# Tool Arguments: {'query': {'description': None, 'type': 'str'}}
# Tool Description: Useful for search-based queries. Use this to find current information about any query related pages using a search engine
#
# IMPORTANT: Use the following format in your response:
#
# ```
# Thought: you should always think about what to do
# Action: the action to take, only one name of [search_engine_tool], just the name, exactly as it's written.
# Action Input: the input to the action, just a simple JSON object, enclosed in curly braces, using " to wrap keys and values.
# Observation: the result of the action
# ```
#
# Once all necessary information is gathered, return the following format:
#
# ```
# Thought: I now know the final answer
# Final Answer: the final answer to the original input question
# ```
#
#
# # Agent: Search Engine Agent
# ## Thought: json
# {
#   "results": [
#     {
#       "title": "De'Longhi - Coffee, Tea & Espresso / Kitchen & Dining",
#       "url": "https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s?rh=n%3A21863852031%2Cp_89%3ADe%2527Longhi",
#       "content": "Price, product pageEGP 890.00 EGP 890.00 List: EGP 1,299.00 List: EGP 1,299.00 EGP1,299.00 *   [- [x] Fulfilled by Amazon](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Free Shipping All customers get FREE Shipping on orders shipped by Amazon](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? i=home&rh=n%3A21863852031%2Cp_89%3ADe%2527Longhi%2Cp_n_free_shipping_eligible%3A21909080031&dc&language=en&qid=1752169469&rnid=21909079031&ref=sr_nr_p_n_free_shipping_eligible_1&ds=v1%3Af7IWxIXQKfkZlZbd5Gvv%2BSkDz83Yatenbw3fOaWQrpY) *   [- [x] Get It by Tomorrow](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] De'Longhi](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Black & Decker](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Arzum Okka](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Nespresso](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Mienta](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Tornado](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] PHILIPS](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] NESCAFÉ DOLCE GUSTO](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Arzum](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Amazon.eg](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Rose Smile Store](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] NM-Espresso](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] QTECH.STORE](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Oxeev](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] Ocean Electronics](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s? *   [- [x] LaialStore](https://www.amazon.eg/-/en/Coffee-Tea-Espresso-DeLonghi-Kitchen-Dining/s?",
#       "score": 0.8747745,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "De'Longhi ecp 31.21 coffee machine (black, 1100w)",
#       "url": "https://www.amazon.eg/-/en/DeLonghi-31-21-coffee-machine-black/dp/B013GDEAI0",
#       "content": "Buy De'Longhi ecp 31.21 coffee machine (black, 1100w) online on Amazon.eg at best prices. ✓ Fast and Free Shipping ✓ Free Returns ✓Cash on Delivery",
#       "score": 0.80771893,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "De'Longhi - Coffee Machines",
#       "url": "https://www.amazon.eg/-/en/Espresso-Machines-DeLonghi-Coffee/s?rh=n%3A21864618031%2Cp_89%3ADe%2527Longhi",
#       "content": "De'Longhi - Espresso Machines / Coffee Machines : Shop online for a large selection of top brands in Egypt ... De'Longhi ecp 31.21 coffee machine (black, 1100w).",
#       "score": 0.6504012,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "Delonghi: Shop Online At Best Prices In Egypt",
#       "url": "https://www.amazon.eg/-/en/delonghi/s?k=delonghi",
#       "content": "Delonghi Ec221 Pump Espresso & Coffee Machine, 1.4L, Black ... Only 2 left in stock - order soon.",
#       "score": 0.54492307,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "De'Longhi Rivelia EXAM440.55.W, Fully Automatic Coffee ...",
#       "url": "https://www.amazon.eg/-/en/DeLonghi-Rivelia-EXAM440-55-W-Automatic-LatteCrema/dp/B0CDCM3J5G",
#       "content": "Fully Automatic Coffee Maker with LatteCrema, Automatic Milk Frother, Compact Size, Bean-to-Cup Coffee Maker, 16 Recipes, Colored Touch Display, Arctic White",
#       "score": 0.32088566,
#       "search_query": "site:www.amazon.eg 'De'Longhi coffee machine' in Egypt"
#     },
#     {
#       "title": "Nespresso Inissia Coffee Machine Black",
#       "url": "https://www.jumia.com.eg/nespresso-inissia-coffee-machine-black-133536518.html?srsltid=AfmBOoq3MML5Yk3jZ5qXcQulpC-r38aFThKjqz-bo5pZ1CMCRnsuvtda",
#       "content": "Nespresso Inissia Coffee Machine Black. Brand:Nespresso|Similar products from Nespresso. EGP 8,569.00. Few units left. Free delivery to 6th of",
#       "score": 0.69399214,
#       "search_query": "site:www.jumia.com.eg 'Nespresso coffee machine' Egypt"
#     },
#     {
#       "title": "Nespresso Coffee Machines - Best Prices in Egypt",
#       "url": "https://www.jumia.com.eg/coffee-machines/nespresso/?srsltid=AfmBOop0Tr93xKdpASBt9R9LkErAVxzDStcTUWzcpsBz5Bv7-J2MHoxh",
#       "content": "Nespresso Coffee Machine, 6 Cups, 19 Bars, 1260W, with Aeroccino 3 Milk Frother, Black - D40-BK. EGP 10,999.00EGP 13,500.00. Add to cart.",
#       "score": 0.66621506,
#       "search_query": "site:www.jumia.com.eg 'Nespresso coffee machine' Egypt"
#     },
#     {
#       "title": "Buy Nespresso Machines at Best Prices",
#       "url": "https://www.jumia.com.eg/mlp-nespresso-machines/?srsltid=AfmBOorRhywqweFQ83vKw1p92u9yVUOWpi-hBJUo42xjYzCH7Io0nVyW",
#       "content": "Nespresso Coffee Machine, 6 Cups, 19 Bars, 1260W, with Aeroccino 3 Milk Frother, Black - D40-BK. EGP 10,999.00EGP 13,500.00. Add to cart.",
#       "score": 0.6580885,
#       "search_query": "site:www.jumia.com.eg 'Nespresso coffee machine' Egypt"
#     },
#     {
#       "title": "Nespresso Super-Automatic Espresso Machines",
#       "url": "https://www.jumia.com.eg/super-automatic-espresso-machines/nespresso/?srsltid=AfmBOopDWq8iU2_s4p_HSvNg72BCjgsWxX27Kz8Zs6lzsW9ivQRhic6f",
#       "content": "Wide Selection of Nespresso Super-Automatic Espresso Machines in Egypt ... Nespresso Inissia Coffee Machine Black. EGP 8,569.00. Add to cart. Sort by",
#       "score": 0.61668247,
#       "search_query": "site:www.jumia.com.eg 'Nespresso coffee machine' Egypt"
#     },
#     {
#       "title": "Coffee Machine, 6 Cups, 19 Bars, 1260W, with Aeroccino ...",
#       "url": "https://www.jumia.com.eg/nespresso-coffee-machine-6-cups-19-bars-1260w-with-aeroccino-3-milk-frother-black-d40-bk-133386173.html?srsltid=AfmBOopnrIHA0M8UVycrzs7dMfwMqQKqelhCnyrwSnaMb4zX39c0QOfQ",
#       "content": "Get Nespresso Coffee Machine, 6 Cups, 19 Bars, 1260W, with Aeroccino 3 Milk Frother, Black - D40-BK online at Jumia and other Nespresso Coffee Machines at",
#       "score": 0.5843666,
#       "search_query": "site:www.jumia.com.eg 'Nespresso coffee machine' Egypt"
#     },
#     {
#       "title": "Home & Kitchen Egypt | Best Price Offers | Cairo, Giza",
#       "url": "https://www.noon.com/egypt-en/home-and-kitchen/?f[new_arrivals][]=30_days&sort[by]=popularity&sort[dir]=desc&limit=50&page=1&isCarouselView=false",
#       "content": "Nespresso Essenza Mini Coffee Machine - 0.6 L 1 W C30-EU2-SI-NE Silver ... Leakproof Design and Great Gift for Outdoor, Office, Home, Sports - Coffee ... Siemens",
#       "score": 0.4654124,
#       "search_query": "site:www.noon.com/egypt-en 'Siemens coffee machine' office use"
#     },
#     {
#       "title": "Kitchen & Home Appliances Egypt | Best Price Offers | Cairo, Giza",
#       "url": "https://www.noon.com/egypt-en/home-and-kitchen/home-appliances-31235/eg-kitchen-appliances/?f[is_fbn][]=1&sort[by]=new_arrivals&sort[dir]=desc&limit=50&page=1&isCarouselView=false",
#       "content": "Electric Coffee Pot 800W – Compact & Easy Use – 0.5L Capacity ... Nespresso Essenza Mini Coffee Machine - 0.6 L 1 W C30-EU2-SI-NE Silver ... Siemens Air",
#       "score": 0.28188768,
#       "search_query": "site:www.noon.com/egypt-en 'Siemens coffee machine' office use"
#     },
#     {
#       "title": "Black & White Kitchen & Home Appliances Egypt",
#       "url": "https://www.noon.com/egypt-en/home-and-kitchen/home-appliances-31235/black_and_white/",
#       "content": "Shop for Black & White Kitchen & Home Appliances on noon. ✓ Secure Shopping ✓ 100% Contactless ✓ Fast Shipping ✓ Cash on Delivery ✓ Easy Free Returns.",
#       "score": 0.23393422,
#       "search_query": "site:www.noon.com/egypt-en 'Siemens coffee machine' office use"
#     },
#     {
#       "title": "Arzum Kitchen & Home Appliances Egypt | 30-75% OFF",
#       "url": "https://www.noon.com/egypt-en/home-and-kitchen/home-appliances-31235/arzum/",
#       "content": "Arzum Okka Espresso Pro fully Automatic Espresso Machine,1.8L Water Capacity, Double Espresso, Americano, Cold Americano, Powdered Coffee, Milk Foam,",
#       "score": 0.10296147,
#       "search_query": "site:www.noon.com/egypt-en 'Siemens coffee machine' office use"
#     },
#     {
#       "title": "Bosch Fully Automatic Coffee machine Series 2 bean ...",
#       "url": "https://www.amazon.eg/-/en/Bosch-Automatic-container-Capacity-TIE20119/dp/B0CP4JY87P",
#       "content": "EGP35,999.00 ; FREE delivery Wednesday, 30 July ; Fulfilled by. Amazon ; Sold by. المفيد-للتجاره ; Brand · bosch",
#       "score": 0.6391287,
#       "search_query": "site:www.amazon.eg 'Bosch coffee machine' with grinder Egypt"
#     },
#     {
#       "title": "TIS30129RW - Fully automatic coffee machine VeroCup 100",
#       "url": "https://www.amazon.eg/-/en/Bosch-TIS30129RW-automatic-machine-VeroCup/dp/B07HLD1THX",
#       "content": "Bosch Fully automatic coffee machine VeroCup 100; Color : Black; Package ... Ceramic grinder: Lasting enjoyment thanks to a high-quality grinder made of",
#       "score": 0.3599269,
#       "search_query": "site:www.amazon.eg 'Bosch coffee machine' with grinder Egypt"
#     },
#     {
#       "title": "Bosch - Coffee, Tea & Espresso / Kitchen & Dining",
#       "url": "https://www.amazon.eg/-/en/Coffee-Tea-Espresso-Bosch-Kitchen-Dining/s?rh=n%3A21863852031%2Cp_89%3ABosch",
#       "content": "Bosch Coffee Electric Grinder 150G/Min, 180 W, Black – TSM6A013B · Plastic ... Bosch Coffee Machine Digital With Milk container Vero Barista 600 - TIS65621RW.",
#       "score": 0.3369858,
#       "search_query": "site:www.amazon.eg 'Bosch coffee machine' with grinder Egypt"
#     },
#     {
#       "title": "Bosch coffee machine Full automatic, Vero Barista, 1500 W",
#       "url": "https://www.amazon.eg/-/en/Bosch-coffee-machine-automatic-Barista/dp/B09P3WWFLS",
#       "content": "Special Features: Timer, Water Filter, Milk Frother, Permanent Filter, Thermal. Coffee Maker Type: Espresso Machine. Material: Ceramic.",
#       "score": 0.26213333,
#       "search_query": "site:www.amazon.eg 'Bosch coffee machine' with grinder Egypt"
#     }
#   ]
# }
# Now I will proceed with the fifth search query.
# Thought: Now I will search for the fifth query and add the results to the JSON object.
# ## Using tool: search_engine_tool
# ## Tool Input:
# "{\"query\": \"site:www.jumia.com.eg 'Philips coffee machine' with milk frother Egypt\"}"
# ## Tool Output:
# ...
#   "error": {
#     "code": 503,
#     "message": "The model is overloaded. Please try again later.",
#     "status": "UNAVAILABLE"
#   }
# }
#
# 🖇 AgentOps: Error in span crewai.workflow: litellm.InternalServerError: litellm.InternalServerError: VertexAIException - {
#   "error": {
#     "code": 503,
#     "message": "The model is overloaded. Please try again later.",
#     "status": "UNAVAILABLE"
#   }
# }
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#  Error during LLM call: litellm.InternalServerError: litellm.InternalServerError: VertexAIException - {
#   "error": {
#     "code": 503,
#     "message": "The model is overloaded. Please try again later.",
#     "status": "UNAVAILABLE"
#   }
# }
#
#  An unknown error occurred. Please check the details below.
#  Error details: litellm.InternalServerError: litellm.InternalServerError: VertexAIException - {
#   "error": {
#     "code": 503,
#     "message": "The model is overloaded. Please try again later.",
#     "status": "UNAVAILABLE"
#   }
# }
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/litellm/llms/vertex_ai/gemini/vertex_and_google_ai_studio_gemini.py in completion(self, model, messages, model_response, print_verbose, custom_llm_provider, encoding, logging_obj, optional_params, acompletion, timeout, vertex_project, vertex_location, vertex_credentials, gemini_api_key, litellm_params, logger_fn, extra_headers, client, api_base)
#    1889         try:
# -> 1890             response = client.post(url=url, headers=headers, json=data)  # type: ignore
#    1891             response.raise_for_status()
#
# /usr/local/lib/python3.11/dist-packages/litellm/llms/custom_httpx/http_handler.py in post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     779             setattr(e, "status_code", e.response.status_code)
# --> 780             raise e
#     781         except Exception as e:
#
# /usr/local/lib/python3.11/dist-packages/litellm/llms/custom_httpx/http_handler.py in post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     761             response = self.client.send(req, stream=stream)
# --> 762             response.raise_for_status()
#     763             return response
#
# /usr/local/lib/python3.11/dist-packages/httpx/_models.py in raise_for_status(self)
#     762         message = message.format(self, error_type=error_type)
# --> 763         raise HTTPStatusError(message, request=request, response=self)
#     764
#
# HTTPStatusError: Server error '503 Service Unavailable' for url 'https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent?key=AIzaSyBGhom9FJfZRC4kRiBfy4dyh1I_v4EAcoA'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/503
#
# During handling of the above exception, another exception occurred:
#
# VertexAIError                             Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/litellm/main.py in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    2605             new_params = deepcopy(optional_params)
# -> 2606             response = vertex_chat_completion.completion(  # type: ignore
#    2607                 model=model,
#
# /usr/local/lib/python3.11/dist-packages/litellm/llms/vertex_ai/gemini/vertex_and_google_ai_studio_gemini.py in completion(self, model, messages, model_response, print_verbose, custom_llm_provider, encoding, logging_obj, optional_params, acompletion, timeout, vertex_project, vertex_location, vertex_credentials, gemini_api_key, litellm_params, logger_fn, extra_headers, client, api_base)
#    1893             error_code = err.response.status_code
# -> 1894             raise VertexAIError(
#    1895                 status_code=error_code,
#
# VertexAIError: {
#   "error": {
#     "code": 503,
#     "message": "The model is overloaded. Please try again later.",
#     "status": "UNAVAILABLE"
#   }
# }
#
#
# During handling of the above exception, another exception occurred:
#
# InternalServerError                       Traceback (most recent call last)
# /tmp/ipython-input-15-1106350321.py in <cell line: 0>()
# ----> 1 crew_results = rankyx_crew.kickoff(
#       2     inputs={
#       3         "product_name": "coffee machine for the office",
#       4         "websites_list": ["www.amazon.eg", "www.jumia.com.eg", "www.noon.com/egypt-en"],
#       5         "country_name": "Egypt",
#
# /usr/local/lib/python3.11/dist-packages/agentops/instrumentation/common/instrumentor.py in wrapper(wrapped, instance, args, kwargs)
#     139     def factory(tracer: Tracer):
#     140         def wrapper(wrapped, instance, args, kwargs):
# --> 141             return wrapper_func(
#     142                 tracer, *wrapper_args, wrapped=wrapped, instance=instance, args=args, kwargs=kwargs, **wrapper_kwargs
#     143             )
#
# /usr/local/lib/python3.11/dist-packages/agentops/instrumentation/agentic/crewai/instrumentation.py in wrap_kickoff_impl(tracer, metrics, attr_manager, wrapped, instance, args, kwargs)
#     182
#     183         logger.debug("CrewAI: Executing wrapped crew kickoff function")
# --> 184         result = wrapped(*args, **kwargs)
#     185
#     186         if result:
#
# /usr/local/lib/python3.11/dist-packages/crewai/crew.py in kickoff(self, inputs)
#     644
#     645             if self.process == Process.sequential:
# --> 646                 result = self._run_sequential_process()
#     647             elif self.process == Process.hierarchical:
#     648                 result = self._run_hierarchical_process()
#
# /usr/local/lib/python3.11/dist-packages/crewai/crew.py in _run_sequential_process(self)
#     756     def _run_sequential_process(self) -> CrewOutput:
#     757         """Executes tasks sequentially and returns the final output."""
# --> 758         return self._execute_tasks(self.tasks)
#     759
#     760     def _run_hierarchical_process(self) -> CrewOutput:
#
# /usr/local/lib/python3.11/dist-packages/crewai/crew.py in _execute_tasks(self, tasks, start_index, was_replayed)
#     859
#     860                 context = self._get_context(task, task_outputs)
# --> 861                 task_output = task.execute_sync(
#     862                     agent=agent_to_use,
#     863                     context=context,
#
# /usr/local/lib/python3.11/dist-packages/agentops/instrumentation/common/instrumentor.py in wrapper(wrapped, instance, args, kwargs)
#     139     def factory(tracer: Tracer):
#     140         def wrapper(wrapped, instance, args, kwargs):
# --> 141             return wrapper_func(
#     142                 tracer, *wrapper_args, wrapped=wrapped, instance=instance, args=args, kwargs=kwargs, **wrapper_kwargs
#     143             )
#
# /usr/local/lib/python3.11/dist-packages/agentops/instrumentation/agentic/crewai/instrumentation.py in wrap_task_execute_impl(tracer, metrics, attr_manager, wrapped, instance, args, kwargs)
#     371         CrewAISpanAttributes(span=span, instance=instance)
#     372
# --> 373         result = wrapped(*args, **kwargs)
#     374
#     375         set_span_attribute(span, SpanAttributes.AGENTOPS_ENTITY_OUTPUT, str(result))
#
# /usr/local/lib/python3.11/dist-packages/crewai/task.py in execute_sync(self, agent, context, tools)
#     326     ) -> TaskOutput:
#     327         """Execute the task synchronously."""
# --> 328         return self._execute_core(agent, context, tools)
#     329
#     330     @property
#
# /usr/local/lib/python3.11/dist-packages/crewai/task.py in _execute_core(self, agent, context, tools)
#     470             self.end_time = datetime.datetime.now()
#     471             crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))
# --> 472             raise e  # Re-raise the exception after emitting the event
#     473
#     474     def prompt(self) -> str:
#
# /usr/local/lib/python3.11/dist-packages/crewai/task.py in _execute_core(self, agent, context, tools)
#     390             self.processed_by_agents.add(agent.role)
#     391             crewai_event_bus.emit(self, TaskStartedEvent(context=context, task=self))
# --> 392             result = agent.execute_task(
#     393                 task=self,
#     394                 context=context,
#
# /usr/local/lib/python3.11/dist-packages/agentops/instrumentation/common/instrumentor.py in wrapper(wrapped, instance, args, kwargs)
#     139     def factory(tracer: Tracer):
#     140         def wrapper(wrapped, instance, args, kwargs):
# --> 141             return wrapper_func(
#     142                 tracer, *wrapper_args, wrapped=wrapped, instance=instance, args=args, kwargs=kwargs, **wrapper_kwargs
#     143             )
#
# /usr/local/lib/python3.11/dist-packages/agentops/instrumentation/agentic/crewai/instrumentation.py in wrap_agent_execute_task_impl(tracer, metrics, attr_manager, wrapped, instance, args, kwargs)
#     320         CrewAISpanAttributes(span=span, instance=instance)
#     321
# --> 322         result = wrapped(*args, **kwargs)
#     323
#     324         attach_tool_executions_to_agent_span(span)
#
# /usr/local/lib/python3.11/dist-packages/crewai/agent.py in execute_task(self, task, context, tools)
#     267                     ),
#     268                 )
# --> 269                 raise e
#     270             self._times_executed += 1
#     271             if self._times_executed > self.max_retry_limit:
#
# /usr/local/lib/python3.11/dist-packages/crewai/agent.py in execute_task(self, task, context, tools)
#     248                 ),
#     249             )
# --> 250             result = self.agent_executor.invoke(
#     251                 {
#     252                     "input": task_prompt,
#
# /usr/local/lib/python3.11/dist-packages/crewai/agents/crew_agent_executor.py in invoke(self, inputs)
#     121             if e.__class__.__module__.startswith("litellm"):
#     122                 # Do not retry on litellm errors
# --> 123                 raise e
#     124             else:
#     125                 raise e
#
# /usr/local/lib/python3.11/dist-packages/crewai/agents/crew_agent_executor.py in invoke(self, inputs)
#     110
#     111         try:
# --> 112             formatted_answer = self._invoke_loop()
#     113         except AssertionError:
#     114             self._printer.print(
#
# /usr/local/lib/python3.11/dist-packages/crewai/agents/crew_agent_executor.py in _invoke_loop(self)
#     206                 if e.__class__.__module__.startswith("litellm"):
#     207                     # Do not retry on litellm errors
# --> 208                     raise e
#     209                 if is_context_length_exceeded(e):
#     210                     handle_context_length(
#
# /usr/local/lib/python3.11/dist-packages/crewai/agents/crew_agent_executor.py in _invoke_loop(self)
#     153                 enforce_rpm_limit(self.request_within_rpm_limit)
#     154
# --> 155                 answer = get_llm_response(
#     156                     llm=self.llm,
#     157                     messages=self.messages,
#
# /usr/local/lib/python3.11/dist-packages/crewai/utilities/agent_utils.py in get_llm_response(llm, messages, callbacks, printer)
#     155             color="red",
#     156         )
# --> 157         raise e
#     158     if not answer:
#     159         printer.print(
#
# /usr/local/lib/python3.11/dist-packages/crewai/utilities/agent_utils.py in get_llm_response(llm, messages, callbacks, printer)
#     146     """Call the LLM and return the response, handling any invalid responses."""
#     147     try:
# --> 148         answer = llm.call(
#     149             messages,
#     150             callbacks=callbacks,
#
# /usr/local/lib/python3.11/dist-packages/agentops/instrumentation/common/instrumentor.py in wrapper(wrapped, instance, args, kwargs)
#     139     def factory(tracer: Tracer):
#     140         def wrapper(wrapped, instance, args, kwargs):
# --> 141             return wrapper_func(
#     142                 tracer, *wrapper_args, wrapped=wrapped, instance=instance, args=args, kwargs=kwargs, **wrapper_kwargs
#     143             )
#
# /usr/local/lib/python3.11/dist-packages/agentops/instrumentation/agentic/crewai/instrumentation.py in wrap_llm_call_impl(tracer, metrics, attr_manager, wrapped, instance, args, kwargs)
#     385         CrewAISpanAttributes(span=span, instance=instance)
#     386
# --> 387         result = wrapped(*args, **kwargs)
#     388
#     389         # Set prompt attributes from args
#
# /usr/local/lib/python3.11/dist-packages/crewai/llm.py in call(self, messages, tools, callbacks, available_functions)
#     792                     )
#     793                 else:
# --> 794                     return self._handle_non_streaming_response(
#     795                         params, callbacks, available_functions
#     796                     )
#
# /usr/local/lib/python3.11/dist-packages/crewai/llm.py in _handle_non_streaming_response(self, params, callbacks, available_functions)
#     628         """
#     629         # --- 1) Make the completion call
# --> 630         response = litellm.completion(**params)
#     631
#     632         # --- 2) Extract response message and content
#
# /usr/local/lib/python3.11/dist-packages/litellm/utils.py in wrapper(*args, **kwargs)
#    1328                     e, traceback_exception, start_time, end_time
#    1329                 )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1330             raise e
#    1331
#    1332     @wraps(original_function)
#
# /usr/local/lib/python3.11/dist-packages/litellm/utils.py in wrapper(*args, **kwargs)
#    1203                     print_verbose(f"Error while checking max token limit: {str(e)}")
#    1204             # MODEL CALL
# -> 1205             result = original_function(*args, **kwargs)
#    1206             end_time = datetime.datetime.now()
#    1207             if _is_streaming_request(
#
# /usr/local/lib/python3.11/dist-packages/litellm/main.py in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    3425     except Exception as e:
#    3426         ## Map to OpenAI Exception
# -> 3427         raise exception_type(
#    3428             model=model,
#    3429             custom_llm_provider=custom_llm_provider,
#
# /usr/local/lib/python3.11/dist-packages/litellm/litellm_core_utils/exception_mapping_utils.py in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2299         if exception_mapping_worked:
#    2300             setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2301             raise e
#    2302         else:
#    2303             for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# /usr/local/lib/python3.11/dist-packages/litellm/litellm_core_utils/exception_mapping_utils.py in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    1282                 ):
#    1283                     exception_mapping_worked = True
# -> 1284                     raise litellm.InternalServerError(
#    1285                         message=f"litellm.InternalServerError: VertexAIException - {error_str}",
#    1286                         model=model,
#
# InternalServerError: litellm.InternalServerError: litellm.InternalServerError: VertexAIException - {
#   "error": {
#     "code": 503,
#     "message": "The model is overloaded. Please try again later.",
#     "status": "UNAVAILABLE"
#   }
# }
